# %%
import pandas as pd

# %%
pd.options.display.max_rows = 77
res = pd.read_csv('results.csv')
res
# Out:
#     Unnamed: 0            name  num_vertices  time_0.1  size_max_clique_0.1  \
# 0            0         C1000.9          1000    185.63                   52
# 1            1          C125.9           125      0.05                   30
# 2            2         C2000.5          2000    322.74                   14
# 3            3          C250.9           250      0.38                   38
# 4            4          C500.9           500      4.24                   44
# 5            5      DSJC1000_5          1000     19.01                   14
# 6            6       DSJC500_5           500      1.28                   11
# 7            7        MANN_a27           378      8.27                  123
# 8            8        MANN_a45          1035    507.19                  335
# 9            9         MANN_a9            45      0.00                   15
# 10          10      brock200_1           200      0.08                   18
# ...
